# %%
import geopandas as gpd
import numpy as np
import pandas as pd

indicators_path = 'data/tracts_indicators_grades_eras_index.csv'
tracts_path = 'data/tracts_shapefile'
crs = {'init':'epsg:4326'}

# %%
decade_names = {'prop_1939_earlier' : 'Pre-1940',
                'prop_1940_49' : '1940s',
                'prop_1950_59' : '1950s',
                'prop_1960_69' : '1960s', 
                'prop_1970_79' : '1970s',
                'prop_1980_89' : '1980s',
                'prop_1990_99' : '1990s',
                'prop_2000_09' : '2000s',
                'prop_2010_later' : '2010s'}

# %%
indicators = pd.read_csv(indicators_path, dtype={'geoid':str})
indicators.shape
# Out:
# (72663, 180)

# %%
tracts = gpd.read_file(tracts_path)
tracts.shape
# Out:
# (74133, 13)

# %%
mask = (indicators['is_urban'] == True) & (indicators['primary_decade'] == 'prop_2010_later')
subset = indicators[mask].set_index('geoid')
subset['latlng'] = tracts.set_index('GEOID')[['INTPTLAT', 'INTPTLON']].astype(float).apply(lambda row: '{},{}'.format(row['INTPTLAT'], row['INTPTLON']), axis=1)

cols = ['latlng', 'state_abbrev', 'grid_index', 'is_urban', 'ztrax_decade', 'prim_ztrax_decade',
        'primary_decade', 'earliest_decade', 'plurality_decade', 'cumulative_decade',
        'year_min', 'year_median', 'year_mean', 'year_std']
subset = subset.reindex(columns=cols).copy()
subset.shape
# Out:
# (213, 14)

# %%
subset.sort_values('grid_index', ascending=False).head(25)
# Out:
#                               latlng state_abbrev  grid_index  is_urban  \
# geoid
# 48245006100   29.8761511,-93.9405661           TX    0.937139         1
# 41039003800  44.0449004,-123.0851827           OR    0.912890         1
# 27053007700    44.950155,-93.2874611           MN    0.903524         1
# 48245006400    29.9034097,-93.924184           TX    0.875924         1
# 42101037700   39.9824381,-75.1506931           PA    0.848183         1
# 04013113100   33.4550381,-112.073874           AZ    0.840951         1
# 27053103900    44.982613,-93.2350036           MN    0.833415         1
# 22071013800   29.9961591,-90.0800463           LA    0.833405         1
# 48167724600   29.2976535,-94.8080731           TX    0.833012         1
# 51510201600   38.8115069,-77.0516818           VA    0.825111         1
# 06075022600   37.762479,-122.3835595           CA    0.815811         1
# 48201510500   29.7842247,-95.4037969           TX    0.798111         1
# 36047051500   40.7191277,-73.9505297           NY    0.796468         1
# 11001010600    38.903312,-77.0033103           DC    0.790620         1
# 51013102001    38.875426,-77.1106009           VA    0.790263         1
# 29097010600   37.0727436,-94.5039365           MO    0.784503         1
# 29077000200   37.2004083,-93.2830719           MO    0.781673         1
# 53033007200  47.6194539,-122.3431175           WA    0.779892         1
# 42101008801   39.9539319,-75.1984477           PA    0.775654         1
# 36061009900   40.7495435,-74.0091035           NY    0.764981         1
# 22071006900   29.9518368,-90.0915969           LA    0.759947         1
# 36005014300   40.8277474,-73.9121298           NY    0.748981         1
# 36047003700   40.6893926,-73.9847008           NY    0.738951         1
# 36005016700   40.8404808,-73.9021708           NY    0.724653         1
# 11001008702   38.9149406,-77.0014531           DC    0.724418         1
#
#                   ztrax_decade  prim_ztrax_decade   primary_decade  \
# geoid
# 48245006100       prop_1950_59       prop_1950_59  prop_2010_later
# 41039003800  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 27053007700  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 48245006400       prop_1950_59       prop_1950_59  prop_2010_later
# 42101037700  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 04013113100  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 27053103900  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 22071013800                NaN    prop_2010_later  prop_2010_later
# 48167724600  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 51510201600  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 06075022600  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 48201510500  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 36047051500  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 11001010600  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 51013102001       prop_1940_49       prop_1940_49  prop_2010_later
# 29097010600       prop_1980_89       prop_1980_89  prop_2010_later
# 29077000200  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 53033007200  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 42101008801  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 36061009900  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 22071006900                NaN    prop_2010_later  prop_2010_later
# 36005014300  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 36047003700  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 36005016700  prop_1939_earlier  prop_1939_earlier  prop_2010_later
# 11001008702  prop_1939_earlier  prop_1939_earlier  prop_2010_later
#
#                earliest_decade plurality_decade cumulative_decade  year_min  \
# geoid
# 48245006100  prop_1939_earlier  prop_2010_later      prop_1970_79    1940.0
# 41039003800    prop_2010_later  prop_2010_later      prop_1980_89    1865.0
# 27053007700       prop_2000_09  prop_2010_later      prop_2000_09    1885.0
# 48245006400    prop_2010_later  prop_2010_later      prop_1960_69    1940.0
# 42101037700    prop_2010_later  prop_2010_later      prop_1990_99    1875.0
# 04013113100    prop_2010_later  prop_2010_later      prop_1970_79    1890.0
# 27053103900    prop_2010_later  prop_2010_later      prop_1990_99    1880.0
# 22071013800    prop_2010_later  prop_2010_later      prop_2000_09       NaN
# 48167724600       prop_1970_79  prop_2010_later      prop_1970_79    1885.0
# 51510201600    prop_2010_later  prop_2010_later      prop_1990_99    1810.0
# 06075022600  prop_1939_earlier  prop_2010_later      prop_2000_09    1885.0
# 48201510500       prop_2000_09  prop_2010_later      prop_2000_09    1900.0
# 36047051500  prop_1939_earlier  prop_2010_later      prop_2000_09    1880.0
# 11001010600  prop_1939_earlier  prop_2010_later      prop_2000_09    1850.0
# 51013102001    prop_2010_later  prop_2010_later      prop_1970_79    1905.0
# 29097010600    prop_2010_later  prop_2010_later      prop_1970_79    1985.0
# 29077000200    prop_2010_later  prop_2010_later      prop_1980_89    1885.0
# 53033007200       prop_2000_09  prop_2010_later      prop_2000_09    1900.0
# 42101008801  prop_1939_earlier  prop_2010_later      prop_1970_79    1875.0
# 36061009900       prop_2000_09  prop_2010_later   prop_2010_later    1885.0
# 22071006900       prop_2000_09  prop_2010_later      prop_2000_09       NaN
# 36005014300  prop_1939_earlier  prop_2010_later      prop_1980_89    1900.0
# 36047003700    prop_2010_later  prop_2010_later   prop_2010_later    1850.0
# 36005016700    prop_2010_later  prop_2010_later      prop_2000_09    1900.0
# 11001008702  prop_1939_earlier  prop_2010_later      prop_1980_89    1890.0
#
#              year_median    year_mean   year_std
# geoid
# 48245006100       1957.5  1960.277778  20.470368
# 41039003800       1905.0  1905.555556  17.730738
# 27053007700       1900.0  1906.500000  26.039500
# 48245006400       1955.0  1955.526316  11.290942
# 42101037700       1920.0  1919.642857  26.708129
# 04013113100       1915.0  1923.400000  26.446487
# 27053103900       1890.0  1902.000000  27.748874
# 22071013800          NaN          NaN        NaN
# 48167724600       1935.0  1932.500000  20.044593
# 51510201600       1905.0  1908.000000  42.932015
# 06075022600       1930.0  1932.187500  30.874410
# 48201510500       1920.0  1928.958333  27.818479
# 36047051500       1900.0  1901.000000  20.736441
# 11001010600       1900.0  1904.090909  35.678337
# 51013102001       1940.0  1943.571429  37.827931
# 29097010600       1985.0  1985.000000        NaN
# 29077000200       1907.5  1911.000000  22.159707
# 53033007200       1915.0  1921.363636  17.940498
# 42101008801       1907.5  1904.166667  19.343388
# 36061009900       1925.0  1942.727273  46.763428
# 22071006900          NaN          NaN        NaN
# 36005014300       1910.0  1911.250000  11.086779
# 36047003700       1897.5  1890.000000  20.248457
# 36005016700       1910.0  1909.000000   7.416198
# 11001008702       1905.0  1916.428571  22.860863

# %% [markdown]
# ## First, validation of estimated vintage

# %%
indicators[['ztrax_decade', 'prim_ztrax_decade', 'primary_decade', 'earliest_decade', 'plurality_decade', 'cumulative_decade']].apply(lambda se: se.value_counts())
# Out:
#                    ztrax_decade  prim_ztrax_decade  primary_decade  \
# prop_1939_earlier         20528              27826           21151
# prop_1940_49               4976               4411            1550
# prop_1950_59               8846               9058            9232
# prop_1960_69               9269               8224            5645
# prop_1970_79              10859              11625           12368
# prop_1980_89               8807               7169            6951
# prop_1990_99               3713               3164            7800
# prop_2000_09               1412               1094            7160
# prop_2010_later             208                 34             368
#
#                    earliest_decade  plurality_decade  cumulative_decade
# prop_1939_earlier            19552             18096               5751
# prop_1940_49                  1636              1139               3913
# prop_1950_59                  8510              8546               9646
# prop_1960_69                  5730              5356              10479
# prop_1970_79                 12689             12418              16311
# prop_1980_89                  6986              7377              13813
# prop_1990_99                  8242              9115               8624
# prop_2000_09                  4715              9623               3596
# prop_2010_later                159               555                 92

# %%
tract_ids = {'04013810700' : 'chandler',     #1990s
             '06001423400' : 'berkeley',     #1920s
             '36059409200' : 'levittown',    #1940s
             '25025020301' : 'bos wes end',  #1960s
             '25025020101' : 'beacon hill',  #1800s
             '32003005824' : 'vegas sum w',  #2000s vegas summerlin west
             '06001403100' : 'oakland dt',   #1940s
             '06059052526' : 'irvine',       #1970s
             '06067009619' : 'laguna west',  #1990s
             '41051009302' : 'east pdx',     #1950s
             '41051001102' : 'ladds pdx',    #1910s
             '06037214503' : 'park labrea',  #1940s
             '06075033204' : 'parkmerced'}   #1940s

#tract_ids = {'34007605602' : '1930s',
#             '39035187105' : '1940s',
#             '27003050232' : '1990s'}

cols = [c for c in indicators.columns if '_decade' in c]
tract = indicators[indicators['geoid'].isin(tract_ids.keys())]
tract.set_index('geoid')[cols].T.rename(columns=tract_ids).T.drop(columns=['cumulative_decade', 'majority_decade']).replace(decade_names)
# Out:
#             ztrax_decade primary_decade prim_ztrax_decade earliest_decade  \
# geoid
# chandler           1990s          1990s             1990s           1980s
# oakland dt      Pre-1940          2000s          Pre-1940        Pre-1940
# berkeley        Pre-1940       Pre-1940          Pre-1940        Pre-1940
# park labrea        1940s          1940s             1940s           1940s
# irvine             1970s          1970s             1970s           1970s
# laguna west        2000s          1990s             1990s           1990s
# parkmerced         1940s          1940s             1940s           1940s
# beacon hill     Pre-1940       Pre-1940          Pre-1940        Pre-1940
# bos wes end     Pre-1940          1960s          Pre-1940           1960s
# vegas sum w        2000s          2000s             2000s           2000s
# levittown       Pre-1940          1940s          Pre-1940           1940s
# ladds pdx       Pre-1940       Pre-1940          Pre-1940        Pre-1940
# east pdx           1940s          1950s             1940s           1950s
#
#             plurality_decade
# geoid
# chandler               1990s
# oakland dt             2000s
# berkeley            Pre-1940
# park labrea            1940s
# irvine                 1970s
# laguna west            1990s
# parkmerced             1940s
# beacon hill         Pre-1940
# bos wes end            1960s
# vegas sum w            2000s
# levittown              1950s
# ladds pdx           Pre-1940
# east pdx               1950s

# %% [markdown]
# ## Now make descriptive tables

# %%
# which variables go in the tables?
cols = ['primary_decade', 'grid_index', 'orientation_order', 'straightness', 'prop_4way', 
        'prop_deadend', 'k_avg', 'intersect_density', 'length_mean', 'vehicles_per_household',
        'pop_density', 'prop_single_fam', 'med_rooms_per_home', 'mean_household_size', 'med_hh_income',
        'mean_commute_time', 'elevations_iqr', 'grade_mean']

# replace infs with nans to calculate summary stats properly
indicators[cols] = indicators[cols].replace([-np.inf, np.inf], np.nan)

# %%
# descriptive stats for the variables
table3 = indicators[cols].describe().round(3).T
table3.to_csv('data/table3.csv', index=True, encoding='utf-8')
table3
# Out:
#                           count     mean      std     min      25%      50%  \
# grid_index              72659.0    0.421    0.209   0.000    0.256    0.396
# orientation_order       72659.0    0.484    0.316   0.002    0.186    0.466
# straightness            72663.0    0.936    0.046   0.000    0.912    0.940
# prop_4way               72663.0    0.210    0.172   0.000    0.092    0.157
# prop_deadend            72663.0    0.203    0.114   0.000    0.116    0.205
# k_avg                   72663.0    2.528    0.296   0.200    2.332    2.513
# intersect_density       72660.0   34.666   33.318   0.000    6.088   28.296
# length_mean             72663.0  240.322  224.423  13.773  130.482  158.987
# vehicles_per_household  71270.0    1.785    0.443   0.027    1.538    1.834
# pop_density             72660.0    2.087    4.594   0.000    0.125    0.873
# prop_single_fam         72225.0    0.621    0.267   0.000    0.467    0.684
# med_rooms_per_home      72104.0    5.588    1.142   1.300    4.900    5.500
# mean_household_size     72173.0    2.644    0.504   1.030    2.330    2.580
# med_hh_income           72025.0   64.345   32.073   2.499   42.358   57.128
# mean_commute_time       72144.0   26.275    7.238   1.000   21.200   25.500
# elevations_iqr          72663.0   20.229   44.762   0.000    3.259    9.228
# grade_mean              72633.0    0.017    0.014   0.000    0.007    0.013
#
#                             75%        max
# grid_index                0.561      1.000
# orientation_order         0.772      1.000
# straightness              0.969      1.000
# prop_4way                 0.272      1.000
# prop_deadend              0.289      1.000
# k_avg                     2.719      3.686
# intersect_density        52.189    370.754
# length_mean             248.747  20407.200
# vehicles_per_household    2.091      4.333
# pop_density               2.103    100.631
# prop_single_fam           0.826      1.000
# med_rooms_per_home        6.200     10.000
# mean_household_size       2.880     12.500
# med_hh_income            78.417    250.001
# mean_commute_time        30.600     69.100
# elevations_iqr           20.456   1513.799
# grade_mean                0.024      1.185

# %%
# calculate variables' means per decade
groups = indicators[cols].groupby('primary_decade')
vars_decades = groups.mean().round(3)
vars_decades.insert(0, 'observations', groups.size())
table4 = vars_decades.rename(decade_names).T
table4.to_csv('data/table4.csv', index=True, encoding='utf-8')
table4
# Out:
# primary_decade           Pre-1940     1940s     1950s     1960s      1970s  \
# observations            21151.000  1550.000  9232.000  5645.000  12368.000
# grid_index                  0.539     0.562     0.483     0.410      0.357
# orientation_order           0.617     0.661     0.585     0.493      0.421
# straightness                0.961     0.960     0.948     0.934      0.920
# prop_4way                   0.315     0.321     0.241     0.185      0.149
# prop_deadend                0.145     0.125     0.158     0.195      0.245
# k_avg                       2.657     2.688     2.622     2.508      2.436
# intersect_density          48.037    52.482    42.806    36.808     25.663
# length_mean               254.531   165.656   170.966   188.238    259.383
# vehicles_per_household      1.578     1.634     1.776     1.766      1.859
# pop_density                 3.660     3.170     2.069     2.184      1.278
# prop_single_fam             0.558     0.637     0.703     0.622      0.611
# med_rooms_per_home          5.366     5.181     5.580     5.560      5.524
# mean_household_size         2.515     2.790     2.736     2.678      2.621
# med_hh_income              57.311    56.113    64.981    65.368     61.138
# mean_commute_time          26.142    26.380    25.800    25.859     25.331
# elevations_iqr             21.303    10.378    12.052    13.190     25.056
# grade_mean                  0.019     0.014     0.015     0.016      0.017
#
# primary_decade             1980s     1990s     2000s    2010s
# observations            6951.000  7800.000  7160.000  368.000
# grid_index                 0.317     0.286     0.332    0.414
# orientation_order          0.344     0.299     0.359    0.448
# straightness               0.911     0.913     0.919    0.936
# prop_4way                  0.134     0.116     0.144    0.213
# prop_deadend               0.259     0.279     0.250    0.180
# k_avg                      2.411     2.384     2.468    2.585
# intersect_density         26.698    18.427    21.374   33.922
# length_mean              232.266   294.315   249.168  204.406
# vehicles_per_household     1.890     2.018     1.973    1.732
# pop_density                1.240     0.725     0.958    1.588
# prop_single_fam            0.602     0.675     0.682    0.484
# med_rooms_per_home         5.649     6.008     5.978    5.305
# mean_household_size        2.668     2.702     2.802    2.667
# med_hh_income             69.624    72.099    76.416   80.641
# mean_commute_time         27.172    27.078    27.585   25.937
# elevations_iqr            21.627    24.871    21.311   13.956
# grade_mean                 0.017     0.018     0.015    0.013

# %%
# variables' correlation matrix
table5 = indicators[cols].drop(['primary_decade'], axis='columns').corr().round(3)
table5.to_csv('data/table5.csv', index=True, encoding='utf-8')
table5
# Out:
#                         grid_index  orientation_order  straightness  \
# grid_index                   1.000              0.899         0.664
# orientation_order            0.899              1.000         0.577
# straightness                 0.664              0.577         1.000
# prop_4way                    0.900              0.670         0.583
# prop_deadend                -0.735             -0.597        -0.510
# k_avg                        0.627              0.432         0.421
# intersect_density            0.571              0.464         0.413
# length_mean                 -0.266             -0.208        -0.178
# vehicles_per_household      -0.496             -0.396        -0.336
# pop_density                  0.442              0.361         0.296
# prop_single_fam             -0.323             -0.260        -0.170
# med_rooms_per_home          -0.363             -0.344        -0.201
# mean_household_size          0.017              0.060         0.028
# med_hh_income               -0.241             -0.255        -0.186
# mean_commute_time           -0.047             -0.069        -0.009
# elevations_iqr              -0.305             -0.299        -0.336
# grade_mean                  -0.377             -0.416        -0.275
#
#                         prop_4way  prop_deadend  k_avg  intersect_density  \
# grid_index                  0.900        -0.735  0.627              0.571
# orientation_order           0.670        -0.597  0.432              0.464
# straightness                0.583        -0.510  0.421              0.413
# prop_4way                   1.000        -0.708  0.632              0.571
# prop_deadend               -0.708         1.000 -0.728             -0.621
# k_avg                       0.632        -0.728  1.000              0.405
# intersect_density           0.571        -0.621  0.405              1.000
# length_mean                -0.247         0.345 -0.208             -0.516
# vehicles_per_household     -0.518         0.555 -0.280             -0.584
# pop_density                 0.502        -0.402  0.048              0.586
# prop_single_fam            -0.350         0.370 -0.061             -0.470
# med_rooms_per_home         -0.330         0.330 -0.128             -0.326
# mean_household_size        -0.017         0.040 -0.055              0.021
# med_hh_income              -0.177         0.176 -0.168             -0.033
# mean_commute_time           0.036         0.045 -0.195              0.159
# elevations_iqr             -0.225         0.320 -0.224             -0.260
# grade_mean                 -0.251         0.309 -0.290             -0.120
#
#                         length_mean  vehicles_per_household  pop_density  \
# grid_index                   -0.266                  -0.496        0.442
# orientation_order            -0.208                  -0.396        0.361
# straightness                 -0.178                  -0.336        0.296
# prop_4way                    -0.247                  -0.518        0.502
# prop_deadend                  0.345                   0.555       -0.402
# k_avg                        -0.208                  -0.280        0.048
# intersect_density            -0.516                  -0.584        0.586
# length_mean                   1.000                   0.398       -0.238
# vehicles_per_household        0.398                   1.000       -0.538
# pop_density                  -0.238                  -0.538        1.000
# prop_single_fam               0.283                   0.731       -0.496
# med_rooms_per_home            0.127                   0.648       -0.359
# mean_household_size          -0.040                   0.344        0.068
# med_hh_income                -0.091                   0.427       -0.024
# mean_commute_time            -0.016                   0.007        0.314
# elevations_iqr                0.400                   0.218       -0.134
# grade_mean                    0.027                   0.106       -0.074
#
#                         prop_single_fam  med_rooms_per_home  \
# grid_index                       -0.323              -0.363
# orientation_order                -0.260              -0.344
# straightness                     -0.170              -0.201
# prop_4way                        -0.350              -0.330
# prop_deadend                      0.370               0.330
# k_avg                            -0.061              -0.128
# intersect_density                -0.470              -0.326
# length_mean                       0.283               0.127
# vehicles_per_household            0.731               0.648
# pop_density                      -0.496              -0.359
# prop_single_fam                   1.000               0.695
# med_rooms_per_home                0.695               1.000
# mean_household_size               0.235               0.244
# med_hh_income                     0.296               0.618
# mean_commute_time                -0.082               0.074
# elevations_iqr                    0.148               0.065
# grade_mean                        0.067               0.120
#
#                         mean_household_size  med_hh_income  mean_commute_time  \
# grid_index                            0.017         -0.241             -0.047
# orientation_order                     0.060         -0.255             -0.069
# straightness                          0.028         -0.186             -0.009
# prop_4way                            -0.017         -0.177              0.036
# prop_deadend                          0.040          0.176              0.045
# k_avg                                -0.055         -0.168             -0.195
# intersect_density                     0.021         -0.033              0.159
# length_mean                          -0.040         -0.091             -0.016
# vehicles_per_household                0.344          0.427              0.007
# pop_density                           0.068         -0.024              0.314
# prop_single_fam                       0.235          0.296             -0.082
# med_rooms_per_home                    0.244          0.618              0.074
# mean_household_size                   1.000          0.148              0.286
# med_hh_income                         0.148          1.000              0.259
# mean_commute_time                     0.286          0.259              1.000
# elevations_iqr                       -0.052          0.021              0.015
# grade_mean                           -0.125          0.139              0.037
#
#                         elevations_iqr  grade_mean
# grid_index                      -0.305      -0.377
# orientation_order               -0.299      -0.416
# straightness                    -0.336      -0.275
# prop_4way                       -0.225      -0.251
# prop_deadend                     0.320       0.309
# k_avg                           -0.224      -0.290
# intersect_density               -0.260      -0.120
# length_mean                      0.400       0.027
# vehicles_per_household           0.218       0.106
# pop_density                     -0.134      -0.074
# prop_single_fam                  0.148       0.067
# med_rooms_per_home               0.065       0.120
# mean_household_size             -0.052      -0.125
# med_hh_income                    0.021       0.139
# mean_commute_time                0.015       0.037
# elevations_iqr                   1.000       0.408
# grade_mean                       0.408       1.000
