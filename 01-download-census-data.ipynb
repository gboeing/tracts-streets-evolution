# %% [markdown]
# https://api.census.gov/data/2017/acs/acs5/profile/variables.html

# %%
import geopandas  as gpd
import getcensus as gc
import os
import pandas as pd
from keys import census_api_key

input_path = 'data/sampled_graph_filepaths.csv'

# %%
# which census dataset
dataset = 'acs/acs5'

# which vintage year
year = 2017

# which census variables to retrieve for each tract
variables = ['DP05_0001E',    #total pop
             'DP05_0077PE',   #pct pop non-hispanic white alone
             'DP04_0007PE',   #pct single family detached homes
             'DP04_0089E',    #median value of owner occupied units (dollars)
             'DP04_0037E',    #median number of rooms in house
             'DP03_0062E',    #median household income (inf-adj 2017 usd)
             'DP02_0067PE',   #pct bachelor's degree or higher
             'DP03_0025E',    #mean travel time to work (minutes)
             'DP03_0019PE',   #pct commute drove alone
             'DP04_0026PE',   #1939 or earlier (pct housing structure built)
             'DP04_0025PE',   #1940-49
             'DP04_0024PE',   #1950-59
             'DP04_0023PE',   #1960-69
             'DP04_0022PE',   #1970-79
             'DP04_0021PE',   #1980-89
             'DP04_0020PE',   #1990-99
             'DP04_0019PE',   #2000-09
             'DP04_0018PE',   #2010-13
             'DP04_0017PE']   #2014 or later

# %%
tract_filepaths = pd.read_csv(input_path, header=None)[0].sort_values()
tracts = tract_filepaths.map(lambda x: x.split('/')[-1].strip('.graphml'))
len(tracts)
# Out:
# 72663

# %%
# %%time
cd = gc.get_census_tracts_data(tract_fips=tracts, api_key=census_api_key, dataset=dataset,
                               year=year, variables=variables, clean=True)
# Out:
# Downloading 19 census vars in 01001 for 12 tracts.
# Downloading 19 census vars in 01003 for 31 tracts.
# Downloading 19 census vars in 01005 for 9 tracts.
# Downloading 19 census vars in 01007 for 4 tracts.
# Downloading 19 census vars in 01009 for 9 tracts.
# Downloading 19 census vars in 01011 for 3 tracts.
# Downloading 19 census vars in 01013 for 9 tracts.
# Downloading 19 census vars in 01015 for 31 tracts.
# Downloading 19 census vars in 01017 for 9 tracts.
# Downloading 19 census vars in 01019 for 6 tracts.
# Downloading 19 census vars in 01021 for 9 tracts.
# Downloading 19 census vars in 01023 for 4 tracts.
# Downloading 19 census vars in 01025 for 9 tracts.
# Downloading 19 census vars in 01027 for 4 tracts.
# Downloading 19 census vars in 01029 for 4 tracts.
# Downloading 19 census vars in 01031 for 14 tracts.
# Downloading 19 census vars in 01033 for 14 tracts.
# Downloading 19 census vars in 01035 for 5 tracts.
# Downloading 19 census vars in 01037 for 3 tracts.
# Downloading 19 census vars in 01039 for 14 tracts.
# Downloading 19 census vars in 01041 for 6 tracts.
# Downloading 19 census vars in 01043 for 18 tracts.
# Downloading 19 census vars in 01045 for 14 tracts.
# Downloading 19 census vars in 01047 for 15 tracts.
# Downloading 19 census vars in 01049 for 14 tracts.
# Downloading 19 census vars in 01051 for 15 tracts.
# Downloading 19 census vars in 01053 for 9 tracts.
# Downloading 19 census vars in 01055 for 30 tracts.
# Downloading 19 census vars in 01057 for 5 tracts.
# Downloading 19 census vars in 01059 for 9 tracts.
# Downloading 19 census vars in 01061 for 6 tracts.
# Downloading 19 census vars in 01063 for 3 tracts.
# Downloading 19 census vars in 01065 for 6 tracts.
# Downloading 19 census vars in 01067 for 6 tracts.
# Downloading 19 census vars in 01069 for 22 tracts.
# Downloading 19 census vars in 01071 for 11 tracts.
# Downloading 19 census vars in 01073 for 163 tracts.
# Downloading 19 census vars in 01075 for 3 tracts.
# Downloading 19 census vars in 01077 for 22 tracts.
# Downloading 19 census vars in 01079 for 9 tracts.
# Downloading 19 census vars in 01081 for 27 tracts.
# Downloading 19 census vars in 01083 for 16 tracts.
# Downloading 19 census vars in 01085 for 4 tracts.
# Downloading 19 census vars in 01087 for 12 tracts.
# Downloading 19 census vars in 01089 for 73 tracts.
# Downloading 19 census vars in 01091 for 6 tracts.
# Downloading 19 census vars in 01093 for 8 tracts.
# Downloading 19 census vars in 01095 for 18 tracts.
# Downloading 19 census vars in 01097 for 114 tracts.
# Downloading 19 census vars in 01099 for 7 tracts.
# Downloading 19 census vars in 01101 for 65 tracts.
# Downloading 19 census vars in 01103 for 27 tracts.
# Downloading 19 census vars in 01105 for 3 tracts.
# Downloading 19 census vars in 01107 for 5 tracts.
# Downloading 19 census vars in 01109 for 8 tracts.
# Downloading 19 census vars in 01111 for 6 tracts.
# Downloading 19 census vars in 01113 for 13 tracts.
# Downloading 19 census vars in 01115 for 13 tracts.
# Downloading 19 census vars in 01117 for 48 tracts.
# Downloading 19 census vars in 01119 for 4 tracts.
# Downloading 19 census vars in 01121 for 22 tracts.
# Downloading 19 census vars in 01123 for 10 tracts.
# Downloading 19 census vars in 01125 for 47 tracts.
# Downloading 19 census vars in 01127 for 18 tracts.
# Downloading 19 census vars in 01129 for 5 tracts.
# Downloading 19 census vars in 01131 for 4 tracts.
# Downloading 19 census vars in 01133 for 7 tracts.
# Downloading 19 census vars in 02013 for 1 tracts.
# Downloading 19 census vars in 02016 for 1 tracts.
# Downloading 19 census vars in 02020 for 55 tracts.
# Downloading 19 census vars in 02050 for 3 tracts.
# Downloading 19 census vars in 02060 for 1 tracts.
# Downloading 19 census vars in 02068 for 1 tracts.
# Downloading 19 census vars in 02070 for 2 tracts.
# Downloading 19 census vars in 02090 for 19 tracts.
# Downloading 19 census vars in 02100 for 1 tracts.
# Downloading 19 census vars in 02105 for 2 tracts.
# Downloading 19 census vars in 02110 for 6 tracts.
# Downloading 19 census vars in 02122 for 13 tracts.
# Downloading 19 census vars in 02130 for 4 tracts.
# Downloading 19 census vars in 02150 for 5 tracts.
# Downloading 19 census vars in 02158 for 1 tracts.
# Downloading 19 census vars in 02164 for 1 tracts.
# Downloading 19 census vars in 02170 for 24 tracts.
# Downloading 19 census vars in 02180 for 2 tracts.
# Downloading 19 census vars in 02185 for 3 tracts.
# Downloading 19 census vars in 02188 for 2 tracts.
# Downloading 19 census vars in 02195 for 1 tracts.
# Downloading 19 census vars in 02198 for 4 tracts.
# Downloading 19 census vars in 02220 for 2 tracts.
# Downloading 19 census vars in 02230 for 1 tracts.
# Downloading 19 census vars in 02240 for 2 tracts.
# Downloading 19 census vars in 02261 for 3 tracts.
# Downloading 19 census vars in 02275 for 1 tracts.
# Downloading 19 census vars in 02282 for 1 tracts.
# Downloading 19 census vars in 02290 for 4 tracts.
# Downloading 19 census vars in 04001 for 16 tracts.
# Downloading 19 census vars in 04003 for 32 tracts.
# Downloading 19 census vars in 04005 for 28 tracts.
# Downloading 19 census vars in 04007 for 16 tracts.
# Downloading 19 census vars in 04009 for 9 tracts.
# Downloading 19 census vars in 04011 for 3 tracts.
# Downloading 19 census vars in 04012 for 9 tracts.
# Downloading 19 census vars in 04013 for 916 tracts.
# Downloading 19 census vars in 04015 for 43 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:940400,940501,950100,950401,950402,950500,950600,950703,950704,950705,950706,951401,951402,951501,951502,951601,951602,951700,951800,951900,952001,952002,952003,952004,952400,952500,952600,952700,952800,952900,953000,953100,953200,953300,953401,953402,953601,953602,953800,953900,954800,954900,955000&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:04+county:015
# Downloading 19 census vars in 04017 for 31 tracts.
# Downloading 19 census vars in 04019 for 241 tracts.
# Downloading 19 census vars in 04021 for 75 tracts.
# Downloading 19 census vars in 04023 for 10 tracts.
# Downloading 19 census vars in 04025 for 42 tracts.
# Downloading 19 census vars in 04027 for 55 tracts.
# Downloading 19 census vars in 05001 for 8 tracts.
# Downloading 19 census vars in 05003 for 7 tracts.
# Downloading 19 census vars in 05005 for 9 tracts.
# Downloading 19 census vars in 05007 for 49 tracts.
# Downloading 19 census vars in 05009 for 7 tracts.
# Downloading 19 census vars in 05011 for 5 tracts.
# Downloading 19 census vars in 05013 for 2 tracts.
# Downloading 19 census vars in 05015 for 5 tracts.
# Downloading 19 census vars in 05017 for 4 tracts.
# Downloading 19 census vars in 05019 for 5 tracts.
# Downloading 19 census vars in 05021 for 6 tracts.
# Downloading 19 census vars in 05023 for 7 tracts.
# Downloading 19 census vars in 05025 for 2 tracts.
# Downloading 19 census vars in 05027 for 5 tracts.
# Downloading 19 census vars in 05029 for 6 tracts.
# Downloading 19 census vars in 05031 for 17 tracts.
# Downloading 19 census vars in 05033 for 11 tracts.
# Downloading 19 census vars in 05035 for 20 tracts.
# Downloading 19 census vars in 05037 for 6 tracts.
# Downloading 19 census vars in 05039 for 3 tracts.
# Downloading 19 census vars in 05041 for 5 tracts.
# Downloading 19 census vars in 05043 for 5 tracts.
# Downloading 19 census vars in 05045 for 25 tracts.
# Downloading 19 census vars in 05047 for 3 tracts.
# Downloading 19 census vars in 05049 for 2 tracts.
# Downloading 19 census vars in 05051 for 20 tracts.
# Downloading 19 census vars in 05053 for 4 tracts.
# Downloading 19 census vars in 05055 for 9 tracts.
# Downloading 19 census vars in 05057 for 5 tracts.
# Downloading 19 census vars in 05059 for 7 tracts.
# Downloading 19 census vars in 05061 for 3 tracts.
# Downloading 19 census vars in 05063 for 8 tracts.
# Downloading 19 census vars in 05065 for 4 tracts.
# Downloading 19 census vars in 05067 for 5 tracts.
# Downloading 19 census vars in 05069 for 24 tracts.
# Downloading 19 census vars in 05071 for 6 tracts.
# Downloading 19 census vars in 05073 for 2 tracts.
# Downloading 19 census vars in 05075 for 6 tracts.
# Downloading 19 census vars in 05077 for 4 tracts.
# Downloading 19 census vars in 05079 for 4 tracts.
# Downloading 19 census vars in 05081 for 4 tracts.
# Downloading 19 census vars in 05083 for 6 tracts.
# Downloading 19 census vars in 05085 for 16 tracts.
# Downloading 19 census vars in 05087 for 4 tracts.
# Downloading 19 census vars in 05089 for 4 tracts.
# Downloading 19 census vars in 05091 for 12 tracts.
# Downloading 19 census vars in 05093 for 12 tracts.
# Downloading 19 census vars in 05095 for 3 tracts.
# Downloading 19 census vars in 05097 for 3 tracts.
# Downloading 19 census vars in 05099 for 3 tracts.
# Downloading 19 census vars in 05101 for 2 tracts.
# Downloading 19 census vars in 05103 for 6 tracts.
# Downloading 19 census vars in 05105 for 3 tracts.
# Downloading 19 census vars in 05107 for 6 tracts.
# Downloading 19 census vars in 05109 for 3 tracts.
# Downloading 19 census vars in 05111 for 7 tracts.
# Downloading 19 census vars in 05113 for 6 tracts.
# Downloading 19 census vars in 05115 for 11 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:950700,950800,950900,951000,951100,951200,951300,951400,951501,951502,951600&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:05+county:115
# Downloading 19 census vars in 05117 for 3 tracts.
# Downloading 19 census vars in 05119 for 95 tracts.
# Downloading 19 census vars in 05121 for 4 tracts.
# Downloading 19 census vars in 05123 for 6 tracts.
# Downloading 19 census vars in 05125 for 21 tracts.
# Downloading 19 census vars in 05127 for 3 tracts.
# Downloading 19 census vars in 05129 for 3 tracts.
# Downloading 19 census vars in 05131 for 26 tracts.
# Downloading 19 census vars in 05133 for 4 tracts.
# Downloading 19 census vars in 05135 for 4 tracts.
# Downloading 19 census vars in 05137 for 3 tracts.
# Downloading 19 census vars in 05139 for 10 tracts.
# Downloading 19 census vars in 05141 for 5 tracts.
# Downloading 19 census vars in 05143 for 32 tracts.
# Downloading 19 census vars in 05145 for 13 tracts.
# Downloading 19 census vars in 05147 for 2 tracts.
# Downloading 19 census vars in 05149 for 6 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:952301,952302,952401,952402,952500,952600&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:05+county:149
# Downloading 19 census vars in 06001 for 360 tracts.
# Downloading 19 census vars in 06003 for 1 tracts.
# Downloading 19 census vars in 06005 for 9 tracts.
# Downloading 19 census vars in 06007 for 51 tracts.
# Downloading 19 census vars in 06009 for 10 tracts.
# Downloading 19 census vars in 06011 for 5 tracts.
# Downloading 19 census vars in 06013 for 207 tracts.
# Downloading 19 census vars in 06015 for 7 tracts.
# Downloading 19 census vars in 06017 for 42 tracts.
# Downloading 19 census vars in 06019 for 199 tracts.
# Downloading 19 census vars in 06021 for 6 tracts.
# Downloading 19 census vars in 06023 for 30 tracts.
# Downloading 19 census vars in 06025 for 31 tracts.
# Downloading 19 census vars in 06027 for 6 tracts.
# Downloading 19 census vars in 06029 for 151 tracts.
# Downloading 19 census vars in 06031 for 26 tracts.
# Downloading 19 census vars in 06033 for 15 tracts.
# Downloading 19 census vars in 06035 for 9 tracts.
# Downloading 19 census vars in 06037 for 1000 tracts.
# Downloading 19 census vars in 06037 for 1000 tracts.
# Downloading 19 census vars in 06037 for 339 tracts.
# Downloading 19 census vars in 06039 for 23 tracts.
# Downloading 19 census vars in 06041 for 54 tracts.
# Downloading 19 census vars in 06043 for 6 tracts.
# Downloading 19 census vars in 06045 for 20 tracts.
# Downloading 19 census vars in 06047 for 49 tracts.
# Downloading 19 census vars in 06049 for 4 tracts.
# Downloading 19 census vars in 06051 for 3 tracts.
# Downloading 19 census vars in 06053 for 93 tracts.
# Downloading 19 census vars in 06055 for 40 tracts.
# Downloading 19 census vars in 06057 for 20 tracts.
# Downloading 19 census vars in 06059 for 582 tracts.
# Downloading 19 census vars in 06061 for 84 tracts.
# Downloading 19 census vars in 06063 for 7 tracts.
# Downloading 19 census vars in 06065 for 452 tracts.
# Downloading 19 census vars in 06067 for 317 tracts.
# Downloading 19 census vars in 06069 for 11 tracts.
# Downloading 19 census vars in 06071 for 369 tracts.
# Downloading 19 census vars in 06073 for 626 tracts.
# Downloading 19 census vars in 06075 for 195 tracts.
# Downloading 19 census vars in 06077 for 139 tracts.
# Downloading 19 census vars in 06079 for 53 tracts.
# Downloading 19 census vars in 06081 for 158 tracts.
# Downloading 19 census vars in 06083 for 88 tracts.
# Downloading 19 census vars in 06085 for 372 tracts.
# Downloading 19 census vars in 06087 for 52 tracts.
# Downloading 19 census vars in 06089 for 48 tracts.
# Downloading 19 census vars in 06091 for 1 tracts.
# Downloading 19 census vars in 06093 for 14 tracts.
# Downloading 19 census vars in 06095 for 96 tracts.
# Downloading 19 census vars in 06097 for 99 tracts.
# Downloading 19 census vars in 06099 for 94 tracts.
# Downloading 19 census vars in 06101 for 21 tracts.
# Downloading 19 census vars in 06103 for 11 tracts.
# Downloading 19 census vars in 06105 for 5 tracts.
# Downloading 19 census vars in 06107 for 77 tracts.
# Downloading 19 census vars in 06109 for 11 tracts.
# Downloading 19 census vars in 06111 for 173 tracts.
# Downloading 19 census vars in 06113 for 41 tracts.
# Downloading 19 census vars in 06115 for 14 tracts.
# Downloading 19 census vars in 08001 for 97 tracts.
# Downloading 19 census vars in 08003 for 4 tracts.
# Downloading 19 census vars in 08005 for 147 tracts.
# Downloading 19 census vars in 08007 for 4 tracts.
# Downloading 19 census vars in 08009 for 2 tracts.
# Downloading 19 census vars in 08011 for 1 tracts.
# Downloading 19 census vars in 08013 for 68 tracts.
# Downloading 19 census vars in 08014 for 16 tracts.
# Downloading 19 census vars in 08015 for 5 tracts.
# Downloading 19 census vars in 08017 for 1 tracts.
# Downloading 19 census vars in 08019 for 3 tracts.
# Downloading 19 census vars in 08021 for 2 tracts.
# Downloading 19 census vars in 08023 for 2 tracts.
# Downloading 19 census vars in 08025 for 1 tracts.
# Downloading 19 census vars in 08027 for 1 tracts.
# Downloading 19 census vars in 08029 for 7 tracts.
# Downloading 19 census vars in 08031 for 144 tracts.
# Downloading 19 census vars in 08033 for 1 tracts.
# Downloading 19 census vars in 08035 for 61 tracts.
# Downloading 19 census vars in 08037 for 14 tracts.
# Downloading 19 census vars in 08039 for 7 tracts.
# Downloading 19 census vars in 08041 for 130 tracts.
# Downloading 19 census vars in 08043 for 13 tracts.
# Downloading 19 census vars in 08045 for 11 tracts.
# Downloading 19 census vars in 08047 for 1 tracts.
# Downloading 19 census vars in 08049 for 3 tracts.
# Downloading 19 census vars in 08051 for 4 tracts.
# Downloading 19 census vars in 08053 for 1 tracts.
# Downloading 19 census vars in 08055 for 2 tracts.
# Downloading 19 census vars in 08057 for 1 tracts.
# Downloading 19 census vars in 08059 for 138 tracts.
# Downloading 19 census vars in 08061 for 1 tracts.
# Downloading 19 census vars in 08063 for 3 tracts.
# Downloading 19 census vars in 08065 for 2 tracts.
# Downloading 19 census vars in 08067 for 10 tracts.
# Downloading 19 census vars in 08069 for 73 tracts.
# Downloading 19 census vars in 08071 for 6 tracts.
# Downloading 19 census vars in 08073 for 2 tracts.
# Downloading 19 census vars in 08075 for 6 tracts.
# Downloading 19 census vars in 08077 for 29 tracts.
# Downloading 19 census vars in 08079 for 1 tracts.
# Downloading 19 census vars in 08081 for 4 tracts.
# Downloading 19 census vars in 08083 for 7 tracts.
# Downloading 19 census vars in 08085 for 10 tracts.
# Downloading 19 census vars in 08087 for 8 tracts.
# Downloading 19 census vars in 08089 for 7 tracts.
# Downloading 19 census vars in 08091 for 1 tracts.
# Downloading 19 census vars in 08093 for 5 tracts.
# Downloading 19 census vars in 08095 for 2 tracts.
# Downloading 19 census vars in 08097 for 4 tracts.
# Downloading 19 census vars in 08099 for 5 tracts.
# Downloading 19 census vars in 08101 for 55 tracts.
# Downloading 19 census vars in 08103 for 2 tracts.
# Downloading 19 census vars in 08105 for 3 tracts.
# Downloading 19 census vars in 08107 for 8 tracts.
# Downloading 19 census vars in 08109 for 2 tracts.
# Downloading 19 census vars in 08111 for 1 tracts.
# Downloading 19 census vars in 08113 for 4 tracts.
# Downloading 19 census vars in 08115 for 1 tracts.
# Downloading 19 census vars in 08117 for 5 tracts.
# Downloading 19 census vars in 08119 for 6 tracts.
# Downloading 19 census vars in 08121 for 2 tracts.
# Downloading 19 census vars in 08123 for 77 tracts.
# Downloading 19 census vars in 08125 for 2 tracts.
# Downloading 19 census vars in 09001 for 210 tracts.
# Downloading 19 census vars in 09003 for 224 tracts.
# Downloading 19 census vars in 09005 for 51 tracts.
# Downloading 19 census vars in 09007 for 36 tracts.
# Downloading 19 census vars in 09009 for 189 tracts.
# Downloading 19 census vars in 09011 for 64 tracts.
# Downloading 19 census vars in 09013 for 28 tracts.
# Downloading 19 census vars in 09015 for 25 tracts.
# Downloading 19 census vars in 10001 for 32 tracts.
# Downloading 19 census vars in 10003 for 130 tracts.
# Downloading 19 census vars in 10005 for 53 tracts.
# Downloading 19 census vars in 11001 for 179 tracts.
# Downloading 19 census vars in 12001 for 56 tracts.
# Downloading 19 census vars in 12003 for 4 tracts.
# Downloading 19 census vars in 12005 for 43 tracts.
# Downloading 19 census vars in 12007 for 4 tracts.
# Downloading 19 census vars in 12009 for 113 tracts.
# Downloading 19 census vars in 12011 for 360 tracts.
# Downloading 19 census vars in 12013 for 3 tracts.
# Downloading 19 census vars in 12015 for 38 tracts.
# Downloading 19 census vars in 12017 for 27 tracts.
# Downloading 19 census vars in 12019 for 30 tracts.
# Downloading 19 census vars in 12021 for 73 tracts.
# Downloading 19 census vars in 12023 for 12 tracts.
# Downloading 19 census vars in 12027 for 9 tracts.
# Downloading 19 census vars in 12029 for 3 tracts.
# Downloading 19 census vars in 12031 for 173 tracts.
# Downloading 19 census vars in 12033 for 71 tracts.
# Downloading 19 census vars in 12035 for 20 tracts.
# Downloading 19 census vars in 12037 for 4 tracts.
# Downloading 19 census vars in 12039 for 9 tracts.
# Downloading 19 census vars in 12041 for 5 tracts.
# Downloading 19 census vars in 12043 for 3 tracts.
# Downloading 19 census vars in 12045 for 3 tracts.
# Downloading 19 census vars in 12047 for 3 tracts.
# Downloading 19 census vars in 12049 for 6 tracts.
# Downloading 19 census vars in 12051 for 6 tracts.
# Downloading 19 census vars in 12053 for 44 tracts.
# Downloading 19 census vars in 12055 for 26 tracts.
# Downloading 19 census vars in 12057 for 317 tracts.
# Downloading 19 census vars in 12059 for 4 tracts.
# Downloading 19 census vars in 12061 for 30 tracts.
# Downloading 19 census vars in 12063 for 11 tracts.
# Downloading 19 census vars in 12065 for 3 tracts.
# Downloading 19 census vars in 12067 for 2 tracts.
# Downloading 19 census vars in 12069 for 56 tracts.
# Downloading 19 census vars in 12071 for 166 tracts.
# Downloading 19 census vars in 12073 for 68 tracts.
# Downloading 19 census vars in 12075 for 9 tracts.
# Downloading 19 census vars in 12077 for 2 tracts.
# Downloading 19 census vars in 12079 for 5 tracts.
# Downloading 19 census vars in 12081 for 78 tracts.
# Downloading 19 census vars in 12083 for 61 tracts.
# Downloading 19 census vars in 12085 for 34 tracts.
# Downloading 19 census vars in 12086 for 516 tracts.
# Downloading 19 census vars in 12087 for 30 tracts.
# Downloading 19 census vars in 12089 for 12 tracts.
# Downloading 19 census vars in 12091 for 41 tracts.
# Downloading 19 census vars in 12093 for 11 tracts.
# Downloading 19 census vars in 12095 for 205 tracts.
# Downloading 19 census vars in 12097 for 41 tracts.
# Downloading 19 census vars in 12099 for 335 tracts.
# Downloading 19 census vars in 12101 for 133 tracts.
# Downloading 19 census vars in 12103 for 244 tracts.
# Downloading 19 census vars in 12105 for 153 tracts.
# Downloading 19 census vars in 12107 for 16 tracts.
# Downloading 19 census vars in 12109 for 39 tracts.
# Downloading 19 census vars in 12111 for 44 tracts.
# Downloading 19 census vars in 12113 for 25 tracts.
# Downloading 19 census vars in 12115 for 94 tracts.
# Downloading 19 census vars in 12117 for 86 tracts.
# Downloading 19 census vars in 12119 for 19 tracts.
# Downloading 19 census vars in 12121 for 7 tracts.
# Downloading 19 census vars in 12123 for 4 tracts.
# Downloading 19 census vars in 12125 for 3 tracts.
# Downloading 19 census vars in 12127 for 113 tracts.
# Downloading 19 census vars in 12129 for 4 tracts.
# Downloading 19 census vars in 12131 for 11 tracts.
# Downloading 19 census vars in 12133 for 7 tracts.
# Downloading 19 census vars in 13001 for 5 tracts.
# Downloading 19 census vars in 13003 for 3 tracts.
# Downloading 19 census vars in 13005 for 3 tracts.
# Downloading 19 census vars in 13007 for 2 tracts.
# Downloading 19 census vars in 13009 for 9 tracts.
# Downloading 19 census vars in 13011 for 4 tracts.
# Downloading 19 census vars in 13013 for 18 tracts.
# Downloading 19 census vars in 13015 for 15 tracts.
# Downloading 19 census vars in 13017 for 5 tracts.
# Downloading 19 census vars in 13019 for 6 tracts.
# Downloading 19 census vars in 13021 for 44 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:010100,010200,010300,010400,010500,010800,011000,011100,011500,011701,011702,011800,011900,012000,012101,012102,012200,012300,012400,012500,012600,012700,012800,012900,013101,013102,013201,013202,013302,013407,013408,013409,013410,013411,013502,013503,013504,013603,013604,013605,013606,013700,013800,013900&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:021
# Downloading 19 census vars in 13023 for 3 tracts.
# Downloading 19 census vars in 13025 for 3 tracts.
# Downloading 19 census vars in 13027 for 5 tracts.
# Downloading 19 census vars in 13029 for 7 tracts.
# Downloading 19 census vars in 13031 for 12 tracts.
# Downloading 19 census vars in 13033 for 6 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:950100,950200,950400,950500,950700,950900&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:033
# Downloading 19 census vars in 13035 for 3 tracts.
# Downloading 19 census vars in 13037 for 2 tracts.
# Downloading 19 census vars in 13039 for 10 tracts.
# Downloading 19 census vars in 13043 for 3 tracts.
# Downloading 19 census vars in 13045 for 17 tracts.
# Downloading 19 census vars in 13047 for 11 tracts.
# Downloading 19 census vars in 13049 for 2 tracts.
# Downloading 19 census vars in 13051 for 71 tracts.
# Downloading 19 census vars in 13053 for 5 tracts.
# Downloading 19 census vars in 13055 for 6 tracts.
# Downloading 19 census vars in 13057 for 26 tracts.
# Downloading 19 census vars in 13059 for 30 tracts.
# Downloading 19 census vars in 13061 for 1 tracts.
# Downloading 19 census vars in 13063 for 50 tracts.
# Downloading 19 census vars in 13065 for 2 tracts.
# Downloading 19 census vars in 13067 for 120 tracts.
# Downloading 19 census vars in 13069 for 9 tracts.
# Downloading 19 census vars in 13071 for 10 tracts.
# Downloading 19 census vars in 13073 for 20 tracts.
# Downloading 19 census vars in 13075 for 4 tracts.
# Downloading 19 census vars in 13077 for 20 tracts.
# Downloading 19 census vars in 13079 for 3 tracts.
# Downloading 19 census vars in 13081 for 6 tracts.
# Downloading 19 census vars in 13083 for 4 tracts.
# Downloading 19 census vars in 13085 for 3 tracts.
# Downloading 19 census vars in 13087 for 7 tracts.
# Downloading 19 census vars in 13089 for 144 tracts.
# Downloading 19 census vars in 13091 for 6 tracts.
# Downloading 19 census vars in 13093 for 3 tracts.
# Downloading 19 census vars in 13095 for 27 tracts.
# Downloading 19 census vars in 13097 for 20 tracts.
# Downloading 19 census vars in 13099 for 5 tracts.
# Downloading 19 census vars in 13101 for 2 tracts.
# Downloading 19 census vars in 13103 for 10 tracts.
# Downloading 19 census vars in 13105 for 5 tracts.
# Downloading 19 census vars in 13107 for 6 tracts.
# Downloading 19 census vars in 13109 for 3 tracts.
# Downloading 19 census vars in 13111 for 5 tracts.
# Downloading 19 census vars in 13113 for 20 tracts.
# Downloading 19 census vars in 13115 for 20 tracts.
# Downloading 19 census vars in 13117 for 45 tracts.
# Downloading 19 census vars in 13119 for 5 tracts.
# Downloading 19 census vars in 13121 for 204 tracts.
# Downloading 19 census vars in 13123 for 5 tracts.
# Downloading 19 census vars in 13125 for 1 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:010100&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:125
# Downloading 19 census vars in 13127 for 15 tracts.
# Downloading 19 census vars in 13129 for 9 tracts.
# Downloading 19 census vars in 13131 for 6 tracts.
# Downloading 19 census vars in 13133 for 7 tracts.
# Downloading 19 census vars in 13135 for 113 tracts.
# Downloading 19 census vars in 13137 for 8 tracts.
# Downloading 19 census vars in 13139 for 36 tracts.
# Downloading 19 census vars in 13141 for 2 tracts.
# Downloading 19 census vars in 13143 for 5 tracts.
# Downloading 19 census vars in 13145 for 5 tracts.
# Downloading 19 census vars in 13147 for 5 tracts.
# Downloading 19 census vars in 13149 for 3 tracts.
# Downloading 19 census vars in 13151 for 25 tracts.
# Downloading 19 census vars in 13153 for 23 tracts.
# Downloading 19 census vars in 13155 for 2 tracts.
# Downloading 19 census vars in 13157 for 11 tracts.
# Downloading 19 census vars in 13159 for 3 tracts.
# Downloading 19 census vars in 13161 for 3 tracts.
# Downloading 19 census vars in 13163 for 4 tracts.
# Downloading 19 census vars in 13165 for 2 tracts.
# Downloading 19 census vars in 13167 for 3 tracts.
# Downloading 19 census vars in 13169 for 6 tracts.
# Downloading 19 census vars in 13171 for 3 tracts.
# Downloading 19 census vars in 13173 for 2 tracts.
# Downloading 19 census vars in 13175 for 13 tracts.
# Downloading 19 census vars in 13177 for 5 tracts.
# Downloading 19 census vars in 13179 for 14 tracts.
# Downloading 19 census vars in 13181 for 2 tracts.
# Downloading 19 census vars in 13183 for 3 tracts.
# Downloading 19 census vars in 13185 for 25 tracts.
# Downloading 19 census vars in 13187 for 4 tracts.
# Downloading 19 census vars in 13189 for 5 tracts.
# Downloading 19 census vars in 13191 for 4 tracts.
# Downloading 19 census vars in 13193 for 4 tracts.
# Downloading 19 census vars in 13195 for 6 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:020100,020200,020300,020400,020500,020600&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:195
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:020100,020200,020300,020400,020500,020600&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:195
# Downloading 19 census vars in 13197 for 2 tracts.
# Downloading 19 census vars in 13199 for 4 tracts.
# Downloading 19 census vars in 13201 for 3 tracts.
# Downloading 19 census vars in 13205 for 5 tracts.
# Downloading 19 census vars in 13207 for 5 tracts.
# Downloading 19 census vars in 13209 for 3 tracts.
# Downloading 19 census vars in 13211 for 5 tracts.
# Downloading 19 census vars in 13213 for 8 tracts.
# Downloading 19 census vars in 13215 for 53 tracts.
# Downloading 19 census vars in 13217 for 13 tracts.
# Downloading 19 census vars in 13219 for 6 tracts.
# Downloading 19 census vars in 13221 for 4 tracts.
# Downloading 19 census vars in 13223 for 19 tracts.
# Downloading 19 census vars in 13225 for 6 tracts.
# Downloading 19 census vars in 13227 for 6 tracts.
# Downloading 19 census vars in 13229 for 4 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:960100,960200,960300,960400&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:13+county:229
# Downloading 19 census vars in 13231 for 4 tracts.
# Downloading 19 census vars in 13233 for 7 tracts.
# Downloading 19 census vars in 13235 for 3 tracts.
# Downloading 19 census vars in 13237 for 5 tracts.
# Downloading 19 census vars in 13239 for 1 tracts.
# Downloading 19 census vars in 13241 for 5 tracts.
# Downloading 19 census vars in 13243 for 2 tracts.
# Downloading 19 census vars in 13245 for 47 tracts.
# Downloading 19 census vars in 13247 for 15 tracts.
# Downloading 19 census vars in 13249 for 2 tracts.
# Downloading 19 census vars in 13251 for 5 tracts.
# Downloading 19 census vars in 13253 for 3 tracts.
# Downloading 19 census vars in 13255 for 12 tracts.
# Downloading 19 census vars in 13257 for 5 tracts.
# Downloading 19 census vars in 13259 for 2 tracts.
# Downloading 19 census vars in 13261 for 8 tracts.
# Downloading 19 census vars in 13263 for 3 tracts.
# Downloading 19 census vars in 13265 for 1 tracts.
# Downloading 19 census vars in 13267 for 5 tracts.
# Downloading 19 census vars in 13269 for 3 tracts.
# Downloading 19 census vars in 13271 for 3 tracts.
# Downloading 19 census vars in 13273 for 4 tracts.
# Downloading 19 census vars in 13275 for 11 tracts.
# Downloading 19 census vars in 13277 for 9 tracts.
# Downloading 19 census vars in 13279 for 6 tracts.
# Downloading 19 census vars in 13281 for 3 tracts.
# Downloading 19 census vars in 13283 for 2 tracts.
# Downloading 19 census vars in 13285 for 14 tracts.
# Downloading 19 census vars in 13287 for 2 tracts.
# Downloading 19 census vars in 13289 for 2 tracts.
# Downloading 19 census vars in 13291 for 6 tracts.
# Downloading 19 census vars in 13293 for 7 tracts.
# Downloading 19 census vars in 13295 for 13 tracts.
# Downloading 19 census vars in 13297 for 15 tracts.
# Downloading 19 census vars in 13299 for 9 tracts.
# Downloading 19 census vars in 13301 for 2 tracts.
# Downloading 19 census vars in 13303 for 5 tracts.
# Downloading 19 census vars in 13305 for 6 tracts.
# Downloading 19 census vars in 13307 for 2 tracts.
# Downloading 19 census vars in 13309 for 2 tracts.
# Downloading 19 census vars in 13311 for 5 tracts.
# Downloading 19 census vars in 13313 for 18 tracts.
# Downloading 19 census vars in 13315 for 4 tracts.
# Downloading 19 census vars in 13317 for 4 tracts.
# Downloading 19 census vars in 13319 for 3 tracts.
# Downloading 19 census vars in 13321 for 5 tracts.
# Downloading 19 census vars in 15001 for 33 tracts.
# Downloading 19 census vars in 15003 for 239 tracts.
# Downloading 19 census vars in 15005 for 1 tracts.
# Downloading 19 census vars in 15007 for 14 tracts.
# Downloading 19 census vars in 15009 for 35 tracts.
# Downloading 19 census vars in 16001 for 59 tracts.
# Downloading 19 census vars in 16003 for 2 tracts.
# Downloading 19 census vars in 16005 for 22 tracts.
# Downloading 19 census vars in 16007 for 2 tracts.
# Downloading 19 census vars in 16009 for 2 tracts.
# Downloading 19 census vars in 16011 for 8 tracts.
# Downloading 19 census vars in 16013 for 4 tracts.
# Downloading 19 census vars in 16015 for 1 tracts.
# Downloading 19 census vars in 16017 for 9 tracts.
# Downloading 19 census vars in 16019 for 21 tracts.
# Downloading 19 census vars in 16021 for 2 tracts.
# Downloading 19 census vars in 16023 for 1 tracts.
# Downloading 19 census vars in 16025 for 1 tracts.
# Downloading 19 census vars in 16027 for 29 tracts.
# Downloading 19 census vars in 16029 for 2 tracts.
# Downloading 19 census vars in 16031 for 6 tracts.
# Downloading 19 census vars in 16033 for 1 tracts.
# Downloading 19 census vars in 16035 for 2 tracts.
# Downloading 19 census vars in 16037 for 1 tracts.
# Downloading 19 census vars in 16039 for 5 tracts.
# Downloading 19 census vars in 16041 for 2 tracts.
# Downloading 19 census vars in 16043 for 3 tracts.
# Downloading 19 census vars in 16045 for 3 tracts.
# Downloading 19 census vars in 16047 for 2 tracts.
# Downloading 19 census vars in 16049 for 5 tracts.
# Downloading 19 census vars in 16051 for 4 tracts.
# Downloading 19 census vars in 16053 for 5 tracts.
# Downloading 19 census vars in 16055 for 25 tracts.
# Downloading 19 census vars in 16057 for 7 tracts.
# Downloading 19 census vars in 16059 for 3 tracts.
# Downloading 19 census vars in 16061 for 3 tracts.
# Downloading 19 census vars in 16063 for 1 tracts.
# Downloading 19 census vars in 16065 for 6 tracts.
# Downloading 19 census vars in 16067 for 5 tracts.
# Downloading 19 census vars in 16069 for 10 tracts.
# Downloading 19 census vars in 16071 for 1 tracts.
# Downloading 19 census vars in 16073 for 3 tracts.
# Downloading 19 census vars in 16075 for 4 tracts.
# Downloading 19 census vars in 16077 for 2 tracts.
# Downloading 19 census vars in 16079 for 3 tracts.
# Downloading 19 census vars in 16081 for 1 tracts.
# Downloading 19 census vars in 16083 for 14 tracts.
# Downloading 19 census vars in 16085 for 3 tracts.
# Downloading 19 census vars in 16087 for 3 tracts.
# Downloading 19 census vars in 17001 for 18 tracts.
# Downloading 19 census vars in 17003 for 4 tracts.
# Downloading 19 census vars in 17005 for 4 tracts.
# Downloading 19 census vars in 17007 for 7 tracts.
# Downloading 19 census vars in 17009 for 2 tracts.
# Downloading 19 census vars in 17011 for 10 tracts.
# Downloading 19 census vars in 17013 for 2 tracts.
# Downloading 19 census vars in 17015 for 6 tracts.
# Downloading 19 census vars in 17017 for 5 tracts.
# Downloading 19 census vars in 17019 for 43 tracts.
# Downloading 19 census vars in 17021 for 10 tracts.
# Downloading 19 census vars in 17023 for 4 tracts.
# Downloading 19 census vars in 17025 for 4 tracts.
# Downloading 19 census vars in 17027 for 8 tracts.
# Downloading 19 census vars in 17029 for 12 tracts.
# Downloading 19 census vars in 17031 for 1000 tracts.
# Downloading 19 census vars in 17031 for 315 tracts.
# Downloading 19 census vars in 17033 for 6 tracts.
# Downloading 19 census vars in 17035 for 3 tracts.
# Downloading 19 census vars in 17037 for 21 tracts.
# Downloading 19 census vars in 17039 for 5 tracts.
# Downloading 19 census vars in 17041 for 5 tracts.
# Downloading 19 census vars in 17043 for 216 tracts.
# Downloading 19 census vars in 17045 for 5 tracts.
# Downloading 19 census vars in 17047 for 3 tracts.
# Downloading 19 census vars in 17049 for 8 tracts.
# Downloading 19 census vars in 17051 for 7 tracts.
# Downloading 19 census vars in 17053 for 5 tracts.
# Downloading 19 census vars in 17055 for 12 tracts.
# Downloading 19 census vars in 17057 for 12 tracts.
# Downloading 19 census vars in 17059 for 2 tracts.
# Downloading 19 census vars in 17061 for 5 tracts.
# Downloading 19 census vars in 17063 for 10 tracts.
# Downloading 19 census vars in 17065 for 3 tracts.
# Downloading 19 census vars in 17067 for 7 tracts.
# Downloading 19 census vars in 17069 for 2 tracts.
# Downloading 19 census vars in 17071 for 3 tracts.
# Downloading 19 census vars in 17073 for 13 tracts.
# Downloading 19 census vars in 17075 for 9 tracts.
# Downloading 19 census vars in 17077 for 14 tracts.
# Downloading 19 census vars in 17079 for 3 tracts.
# Downloading 19 census vars in 17081 for 11 tracts.
# Downloading 19 census vars in 17083 for 6 tracts.
# Downloading 19 census vars in 17085 for 6 tracts.
# Downloading 19 census vars in 17087 for 4 tracts.
# Downloading 19 census vars in 17089 for 82 tracts.
# Downloading 19 census vars in 17091 for 29 tracts.
# Downloading 19 census vars in 17093 for 10 tracts.
# Downloading 19 census vars in 17095 for 16 tracts.
# Downloading 19 census vars in 17097 for 153 tracts.
# Downloading 19 census vars in 17099 for 28 tracts.
# Downloading 19 census vars in 17101 for 5 tracts.
# Downloading 19 census vars in 17103 for 9 tracts.
# Downloading 19 census vars in 17105 for 10 tracts.
# Downloading 19 census vars in 17107 for 8 tracts.
# Downloading 19 census vars in 17109 for 10 tracts.
# Downloading 19 census vars in 17111 for 52 tracts.
# Downloading 19 census vars in 17113 for 41 tracts.
# Downloading 19 census vars in 17115 for 34 tracts.
# Downloading 19 census vars in 17117 for 13 tracts.
# Downloading 19 census vars in 17119 for 61 tracts.
# Downloading 19 census vars in 17121 for 12 tracts.
# Downloading 19 census vars in 17123 for 5 tracts.
# Downloading 19 census vars in 17125 for 6 tracts.
# Downloading 19 census vars in 17127 for 4 tracts.
# Downloading 19 census vars in 17129 for 3 tracts.
# Downloading 19 census vars in 17131 for 4 tracts.
# Downloading 19 census vars in 17133 for 6 tracts.
# Downloading 19 census vars in 17135 for 8 tracts.
# Downloading 19 census vars in 17137 for 10 tracts.
# Downloading 19 census vars in 17139 for 4 tracts.
# Downloading 19 census vars in 17141 for 11 tracts.
# Downloading 19 census vars in 17143 for 48 tracts.
# Downloading 19 census vars in 17145 for 6 tracts.
# Downloading 19 census vars in 17147 for 4 tracts.
# Downloading 19 census vars in 17149 for 5 tracts.
# Downloading 19 census vars in 17151 for 2 tracts.
# Downloading 19 census vars in 17153 for 2 tracts.
# Downloading 19 census vars in 17155 for 2 tracts.
# Downloading 19 census vars in 17157 for 9 tracts.
# Downloading 19 census vars in 17159 for 5 tracts.
# Downloading 19 census vars in 17161 for 40 tracts.
# Downloading 19 census vars in 17163 for 60 tracts.
# Downloading 19 census vars in 17165 for 9 tracts.
# Downloading 19 census vars in 17167 for 53 tracts.
# Downloading 19 census vars in 17169 for 3 tracts.
# Downloading 19 census vars in 17171 for 2 tracts.
# Downloading 19 census vars in 17173 for 6 tracts.
# Downloading 19 census vars in 17175 for 2 tracts.
# Downloading 19 census vars in 17177 for 13 tracts.
# Downloading 19 census vars in 17179 for 30 tracts.
# Downloading 19 census vars in 17181 for 5 tracts.
# Downloading 19 census vars in 17183 for 24 tracts.
# Downloading 19 census vars in 17185 for 4 tracts.
# Downloading 19 census vars in 17187 for 5 tracts.
# ...
# Downloading 19 census vars in 51181 for 2 tracts.
# Downloading 19 census vars in 51183 for 5 tracts.
# Downloading 19 census vars in 51185 for 11 tracts.
# Downloading 19 census vars in 51187 for 8 tracts.
# Downloading 19 census vars in 51191 for 13 tracts.
# Downloading 19 census vars in 51193 for 4 tracts.
# Downloading 19 census vars in 51195 for 11 tracts.
# Downloading 19 census vars in 51197 for 6 tracts.
# Downloading 19 census vars in 51199 for 14 tracts.
# Downloading 19 census vars in 51510 for 38 tracts.
# Downloading 19 census vars in 51520 for 4 tracts.
# Downloading 19 census vars in 51530 for 1 tracts.
# Downloading 19 census vars in 51540 for 12 tracts.
# Downloading 19 census vars in 51550 for 41 tracts.
# Downloading 19 census vars in 51570 for 5 tracts.
# Downloading 19 census vars in 51580 for 2 tracts.
# Downloading 19 census vars in 51590 for 16 tracts.
# Downloading 19 census vars in 51595 for 2 tracts.
# Downloading 19 census vars in 51600 for 5 tracts.
# Downloading 19 census vars in 51610 for 3 tracts.
# Downloading 19 census vars in 51620 for 2 tracts.
# Downloading 19 census vars in 51630 for 6 tracts.
# Downloading 19 census vars in 51640 for 2 tracts.
# Downloading 19 census vars in 51650 for 33 tracts.
# Downloading 19 census vars in 51660 for 11 tracts.
# Downloading 19 census vars in 51670 for 7 tracts.
# Downloading 19 census vars in 51678 for 1 tracts.
# Downloading 19 census vars in 51680 for 19 tracts.
# Downloading 19 census vars in 51683 for 7 tracts.
# Downloading 19 census vars in 51685 for 2 tracts.
# Downloading 19 census vars in 51690 for 5 tracts.
# Downloading 19 census vars in 51700 for 44 tracts.
# Downloading 19 census vars in 51710 for 80 tracts.
# Downloading 19 census vars in 51720 for 1 tracts.
# Downloading 19 census vars in 51730 for 11 tracts.
# Downloading 19 census vars in 51735 for 3 tracts.
# Downloading 19 census vars in 51740 for 31 tracts.
# Downloading 19 census vars in 51750 for 3 tracts.
# Downloading 19 census vars in 51760 for 66 tracts.
# Downloading 19 census vars in 51770 for 23 tracts.
# Downloading 19 census vars in 51775 for 5 tracts.
# Downloading 19 census vars in 51790 for 6 tracts.
# Downloading 19 census vars in 51800 for 28 tracts.
# Downloading 19 census vars in 51810 for 99 tracts.
# Downloading 19 census vars in 51820 for 5 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:003100,003200,003300,003400,003500&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:51+county:820
# Downloading 19 census vars in 51830 for 3 tracts.
# Downloading 19 census vars in 51840 for 5 tracts.
# Downloading 19 census vars in 53001 for 5 tracts.
# Downloading 19 census vars in 53003 for 6 tracts.
# Downloading 19 census vars in 53005 for 37 tracts.
# Downloading 19 census vars in 53007 for 14 tracts.
# Downloading 19 census vars in 53009 for 21 tracts.
# Downloading 19 census vars in 53011 for 104 tracts.
# Downloading 19 census vars in 53013 for 1 tracts.
# Downloading 19 census vars in 53015 for 24 tracts.
# Downloading 19 census vars in 53017 for 8 tracts.
# Downloading 19 census vars in 53019 for 3 tracts.
# Downloading 19 census vars in 53021 for 13 tracts.
# Downloading 19 census vars in 53023 for 1 tracts.
# Downloading 19 census vars in 53025 for 16 tracts.
# Downloading 19 census vars in 53027 for 16 tracts.
# Downloading 19 census vars in 53029 for 21 tracts.
# Downloading 19 census vars in 53031 for 7 tracts.
# Downloading 19 census vars in 53033 for 397 tracts.
# Downloading 19 census vars in 53035 for 54 tracts.
# Downloading 19 census vars in 53037 for 8 tracts.
# Downloading 19 census vars in 53039 for 3 tracts.
# Downloading 19 census vars in 53041 for 20 tracts.
# Downloading 19 census vars in 53043 for 4 tracts.
# Downloading 19 census vars in 53045 for 14 tracts.
# Downloading 19 census vars in 53047 for 10 tracts.
# Downloading 19 census vars in 53049 for 7 tracts.
# Downloading 19 census vars in 53051 for 5 tracts.
# Downloading 19 census vars in 53053 for 172 tracts.
# Downloading 19 census vars in 53055 for 4 tracts.
# Downloading 19 census vars in 53057 for 29 tracts.
# Downloading 19 census vars in 53059 for 5 tracts.
# Downloading 19 census vars in 53061 for 149 tracts.
# Downloading 19 census vars in 53063 for 105 tracts.
# Downloading 19 census vars in 53065 for 12 tracts.
# Downloading 19 census vars in 53067 for 49 tracts.
# Downloading 19 census vars in 53069 for 1 tracts.
# Downloading 19 census vars in 53071 for 12 tracts.
# Downloading 19 census vars in 53073 for 34 tracts.
# Downloading 19 census vars in 53075 for 10 tracts.
# Downloading 19 census vars in 53077 for 45 tracts.
# Downloading 19 census vars in 54001 for 4 tracts.
# Downloading 19 census vars in 54003 for 14 tracts.
# Downloading 19 census vars in 54005 for 8 tracts.
# Downloading 19 census vars in 54007 for 3 tracts.
# Downloading 19 census vars in 54009 for 6 tracts.
# Downloading 19 census vars in 54011 for 29 tracts.
# Downloading 19 census vars in 54013 for 2 tracts.
# Downloading 19 census vars in 54015 for 3 tracts.
# Downloading 19 census vars in 54017 for 2 tracts.
# Downloading 19 census vars in 54019 for 12 tracts.
# Downloading 19 census vars in 54021 for 2 tracts.
# Downloading 19 census vars in 54023 for 3 tracts.
# Downloading 19 census vars in 54025 for 7 tracts.
# Downloading 19 census vars in 54027 for 5 tracts.
# Downloading 19 census vars in 54029 for 8 tracts.
# Downloading 19 census vars in 54031 for 3 tracts.
# Downloading 19 census vars in 54033 for 22 tracts.
# Downloading 19 census vars in 54035 for 6 tracts.
# Downloading 19 census vars in 54037 for 15 tracts.
# Downloading 19 census vars in 54039 for 53 tracts.
# Downloading 19 census vars in 54041 for 5 tracts.
# Downloading 19 census vars in 54043 for 5 tracts.
# Downloading 19 census vars in 54045 for 9 tracts.
# Downloading 19 census vars in 54047 for 8 tracts.
# Downloading 19 census vars in 54049 for 18 tracts.
# Downloading 19 census vars in 54051 for 9 tracts.
# Downloading 19 census vars in 54053 for 6 tracts.
# Downloading 19 census vars in 54055 for 16 tracts.
# Downloading 19 census vars in 54057 for 7 tracts.
# Downloading 19 census vars in 54059 for 7 tracts.
# Downloading 19 census vars in 54061 for 24 tracts.
# Downloading 19 census vars in 54063 for 3 tracts.
# Downloading 19 census vars in 54065 for 4 tracts.
# Downloading 19 census vars in 54067 for 7 tracts.
# Downloading 19 census vars in 54069 for 18 tracts.
# Downloading 19 census vars in 54071 for 3 tracts.
# Downloading 19 census vars in 54073 for 2 tracts.
# Downloading 19 census vars in 54075 for 4 tracts.
# Downloading 19 census vars in 54077 for 8 tracts.
# Downloading 19 census vars in 54079 for 10 tracts.
# Downloading 19 census vars in 54081 for 17 tracts.
# Downloading 19 census vars in 54083 for 7 tracts.
# Downloading 19 census vars in 54085 for 3 tracts.
# Downloading 19 census vars in 54087 for 4 tracts.
# Downloading 19 census vars in 54089 for 4 tracts.
# Downloading 19 census vars in 54091 for 4 tracts.
# Downloading 19 census vars in 54093 for 3 tracts.
# Downloading 19 census vars in 54095 for 3 tracts.
# Downloading 19 census vars in 54097 for 6 tracts.
# Downloading 19 census vars in 54099 for 11 tracts.
# Downloading 19 census vars in 54101 for 3 tracts.
# Downloading 19 census vars in 54103 for 5 tracts.
# Downloading 19 census vars in 54105 for 2 tracts.
# Downloading 19 census vars in 54107 for 26 tracts.
# Downloading 19 census vars in 54109 for 6 tracts.
# Downloading 19 census vars in 55001 for 7 tracts.
# Downloading 19 census vars in 55003 for 7 tracts.
# Downloading 19 census vars in 55005 for 10 tracts.
# Downloading 19 census vars in 55007 for 5 tracts.
# Downloading 19 census vars in 55009 for 54 tracts.
# Downloading 19 census vars in 55011 for 5 tracts.
# Downloading 19 census vars in 55013 for 6 tracts.
# Downloading 19 census vars in 55015 for 11 tracts.
# Downloading 19 census vars in 55017 for 11 tracts.
# Downloading 19 census vars in 55019 for 8 tracts.
# Downloading 19 census vars in 55021 for 12 tracts.
# Downloading 19 census vars in 55023 for 6 tracts.
# Downloading 19 census vars in 55025 for 105 tracts.
# Downloading 19 census vars in 55027 for 20 tracts.
# Downloading 19 census vars in 55029 for 9 tracts.
# Expecting value: line 1 column 1 (char 0) 500 <html><head><title>Error report</title><style><!--H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}HR {color : #525D76;}--></style> </head><body><h1>HTTP Status 500 - </h1><HR size="1" noshade="noshade"><p><b>type</b> Status report</p><p><b>message</b> <u></u></p><p><b>description</b> <u>The server encountered an internal error that prevented it from fulfilling this request.</u></p><HR size="1" noshade="noshade"></body></html> https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP05_0077PE,DP04_0007PE,DP04_0089E,DP04_0037E,DP03_0062E,DP02_0067PE,DP03_0025E,DP03_0019PE,DP04_0026PE,DP04_0025PE,DP04_0024PE,DP04_0023PE,DP04_0022PE,DP04_0021PE,DP04_0020PE,DP04_0019PE,DP04_0018PE,DP04_0017PE&for=tract:100100,100300,100400,100500,100600,100700,100800,100900,101000&key=eb6ac6d6114c80e602f2599a8fe139d181a8e34f&in=state:55+county:029
# Downloading 19 census vars in 55031 for 12 tracts.
# Downloading 19 census vars in 55033 for 8 tracts.
# Downloading 19 census vars in 55035 for 20 tracts.
# Downloading 19 census vars in 55037 for 2 tracts.
# Downloading 19 census vars in 55039 for 20 tracts.
# Downloading 19 census vars in 55041 for 4 tracts.
# Downloading 19 census vars in 55043 for 12 tracts.
# Downloading 19 census vars in 55045 for 8 tracts.
# Downloading 19 census vars in 55047 for 6 tracts.
# Downloading 19 census vars in 55049 for 6 tracts.
# Downloading 19 census vars in 55051 for 3 tracts.
# Downloading 19 census vars in 55053 for 5 tracts.
# Downloading 19 census vars in 55055 for 20 tracts.
# Downloading 19 census vars in 55057 for 7 tracts.
# Downloading 19 census vars in 55059 for 35 tracts.
# Downloading 19 census vars in 55061 for 4 tracts.
# Downloading 19 census vars in 55063 for 25 tracts.
# Downloading 19 census vars in 55065 for 5 tracts.
# Downloading 19 census vars in 55067 for 6 tracts.
# Downloading 19 census vars in 55069 for 10 tracts.
# Downloading 19 census vars in 55071 for 19 tracts.
# Downloading 19 census vars in 55073 for 27 tracts.
# Downloading 19 census vars in 55075 for 12 tracts.
# Downloading 19 census vars in 55077 for 5 tracts.
# Downloading 19 census vars in 55078 for 2 tracts.
# Downloading 19 census vars in 55079 for 297 tracts.
# Downloading 19 census vars in 55081 for 9 tracts.
# Downloading 19 census vars in 55083 for 10 tracts.
# Downloading 19 census vars in 55085 for 14 tracts.
# Downloading 19 census vars in 55087 for 40 tracts.
# Downloading 19 census vars in 55089 for 18 tracts.
# Downloading 19 census vars in 55091 for 2 tracts.
# Downloading 19 census vars in 55093 for 8 tracts.
# Downloading 19 census vars in 55095 for 10 tracts.
# Downloading 19 census vars in 55097 for 14 tracts.
# Downloading 19 census vars in 55099 for 6 tracts.
# Downloading 19 census vars in 55101 for 44 tracts.
# Downloading 19 census vars in 55103 for 5 tracts.
# Downloading 19 census vars in 55105 for 38 tracts.
# Downloading 19 census vars in 55107 for 5 tracts.
# Downloading 19 census vars in 55109 for 14 tracts.
# Downloading 19 census vars in 55111 for 13 tracts.
# Downloading 19 census vars in 55113 for 6 tracts.
# Downloading 19 census vars in 55115 for 11 tracts.
# Downloading 19 census vars in 55117 for 26 tracts.
# Downloading 19 census vars in 55119 for 6 tracts.
# Downloading 19 census vars in 55121 for 8 tracts.
# Downloading 19 census vars in 55123 for 7 tracts.
# Downloading 19 census vars in 55125 for 5 tracts.
# Downloading 19 census vars in 55127 for 22 tracts.
# Downloading 19 census vars in 55129 for 5 tracts.
# Downloading 19 census vars in 55131 for 28 tracts.
# Downloading 19 census vars in 55133 for 86 tracts.
# Downloading 19 census vars in 55135 for 12 tracts.
# Downloading 19 census vars in 55137 for 7 tracts.
# Downloading 19 census vars in 55139 for 41 tracts.
# Downloading 19 census vars in 55141 for 17 tracts.
# Downloading 19 census vars in 56001 for 10 tracts.
# Downloading 19 census vars in 56003 for 3 tracts.
# Downloading 19 census vars in 56005 for 7 tracts.
# Downloading 19 census vars in 56007 for 5 tracts.
# Downloading 19 census vars in 56009 for 4 tracts.
# Downloading 19 census vars in 56011 for 2 tracts.
# Downloading 19 census vars in 56013 for 10 tracts.
# Downloading 19 census vars in 56015 for 4 tracts.
# Downloading 19 census vars in 56017 for 2 tracts.
# Downloading 19 census vars in 56019 for 2 tracts.
# Downloading 19 census vars in 56021 for 21 tracts.
# Downloading 19 census vars in 56023 for 4 tracts.
# Downloading 19 census vars in 56025 for 18 tracts.
# Downloading 19 census vars in 56027 for 1 tracts.
# Downloading 19 census vars in 56029 for 5 tracts.
# Downloading 19 census vars in 56031 for 2 tracts.
# Downloading 19 census vars in 56033 for 6 tracts.
# Downloading 19 census vars in 56035 for 2 tracts.
# Downloading 19 census vars in 56037 for 12 tracts.
# Downloading 19 census vars in 56039 for 4 tracts.
# Downloading 19 census vars in 56041 for 3 tracts.
# Downloading 19 census vars in 56043 for 3 tracts.
# Downloading 19 census vars in 56045 for 2 tracts.
# Wall time: 2h 15min 2s

# %%
cols = {'DP05_0001E'  : 'total_pop',
        'DP05_0077PE' : 'pct_white',
        'DP04_0007PE' : 'pct_single_fam',
        'DP04_0089E'  : 'med_home_value',
        'DP04_0037E'  : 'med_rooms_per_home',
        'DP04_0026PE' : 'pct_1939_earlier',
        'DP04_0025PE' : 'pct_1940_49',
        'DP04_0024PE' : 'pct_1950_59',
        'DP04_0023PE' : 'pct_1960_69',
        'DP04_0022PE' : 'pct_1970_79',
        'DP04_0021PE' : 'pct_1980_89',
        'DP04_0020PE' : 'pct_1990_99',
        'DP04_0019PE' : 'pct_2000_09',
        'DP04_0018PE' : 'pct_2010_13',
        'DP04_0017PE' : 'pct_2014_later',
        'DP03_0062E'  : 'med_hh_income',
        'DP03_0025E'  : 'mean_commute_time',
        'DP03_0019PE' : 'pct_drive_alone',
        'DP02_0067PE' : 'pct_bachelors_higher'}

df = cd.rename(columns=cols)
len(df)
# Out:
# 72663

# %%
# convert percents to proportions
for col in df.columns:
    if 'pct_' in col:
        new_col = col.replace('pct_', 'prop_')
        df[new_col] = df[col] / 100
        df = df.drop(columns=col)

# %%
# merge post-2010 structures-built columns into one
df['prop_2010_later'] = df['prop_2010_13'] + df['prop_2014_later']
df = df.drop(columns=['prop_2010_13', 'prop_2014_later'])

# %%
df.head()
# Out:
#              total_pop  med_home_value  med_rooms_per_home  med_hh_income  \
# GEOID10
# 01001020801     2913.0        299100.0                 6.7        80089.0
# 01001020802    11333.0        163200.0                 6.1        64439.0
# 01001020200     2172.0         96100.0                 5.6        41287.0
# 01001021000     2796.0         96700.0                 5.9        46607.0
# 01001020300     3385.0         98900.0                 5.8        46806.0
#
#              mean_commute_time state county  prop_white  prop_single_fam  \
# GEOID10
# 01001020801               24.6    01    001       0.863            0.848
# 01001020802               27.4    01    001       0.818            0.757
# 01001020200               22.2    01    001       0.416            0.759
# 01001021000               35.6    01    001       0.715            0.625
# 01001020300               23.1    01    001       0.614            0.854
#
#              prop_bachelors_higher  prop_drive_alone  prop_1939_earlier  \
# GEOID10
# 01001020801                  0.387             0.895              0.048
# 01001020802                  0.245             0.891              0.020
# 01001020200                  0.162             0.905              0.144
# 01001021000                  0.152             0.839              0.064
# 01001020300                  0.181             0.883              0.008
#
#              prop_1940_49  prop_1950_59  prop_1960_69  prop_1970_79  \
# GEOID10
# 01001020801         0.021         0.029         0.011         0.156
# 01001020802         0.015         0.017         0.053         0.107
# 01001020200         0.009         0.047         0.171         0.325
# 01001021000         0.027         0.128         0.046         0.121
# 01001020300         0.022         0.028         0.177         0.369
#
#              prop_1980_89  prop_1990_99  prop_2000_09  prop_2010_later
# GEOID10
# 01001020801         0.188         0.214         0.300            0.033
# 01001020802         0.101         0.235         0.318            0.136
# 01001020200         0.028         0.117         0.159            0.000
# 01001021000         0.179         0.270         0.147            0.017
# 01001020300         0.075         0.157         0.132            0.031

# %%
df.to_csv('data/census_data.csv', index=True, encoding='utf-8')
